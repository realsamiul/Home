# %% [markdown]
# <a href="https://colab.research.google.com/github/realsamiul/Home/blob/main/Copy_of_Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run freight_rate_prediction.py
# Out:
# ✅ yfinance is already installed
# ✅ xgboost is already installed
# ✅ All packages installed/verified
# ✅ Libraries imported successfully
# 📊 Creating historical dataset...
# ✅ Port data simulated: 1096 records
# 📈 Downloading real market data...
# ✅ BDRY data downloaded
# ✅ Brent oil data downloaded
# ✅ Market data acquired
# 🌤️ Simulating weather and news data...
# ✅ Weather and news data simulated
# 🧮 Calculating CCI and GSI indices...
# ✅ Indices calculated
# 🔧 Creating lag features...
# ✅ Features prepared: 1081 records after removing NaN
#
# 📊 Dataset Overview:
# Date range: 2022-01-16 00:00:00 to 2024-12-31 00:00:00
# Total records: 1081
# Features: 30
#
# 📈 Sample data:
#          date  vessel_count  avg_wait_time  berth_availability  BDRY_price  \
# 15 2022-01-16     29.525158      17.887062            9.845249   23.190001
# 16 2022-01-17     27.240716      20.059021            9.143388   23.190001
# 17 2022-01-18     34.590035      18.901280            9.422710   21.000000
# ...
